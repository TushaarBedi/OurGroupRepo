# %%
# Dependencies
import requests
import json
import pandas as pd
# Google developer API key
from config import gkey

# %%
# geocoordinates
#testing with the first listed Charlotte shooting
target_coordinates = "35.2526941601, -80.8497010414"
target_search = "public"
target_radius = 8000
target_type = "library"
# target_coordinates = "43.6187102, -116.2146068"
# target_search = "Chinese"
# target_radius = 8000
# target_type = "restaurant"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key
print(response.url)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=35.2526941601%2C+-80.8497010414&keyword=public&radius=8000&type=library&key=AIzaSyC7B01DdQsxWGTni-MdFTsmSPiHMT5r2Os

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 35.2285169,
#                     "lng": -80.839928
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 35.23012162989272,
#                         "lng": -80.83884877010728
#                     },
#                     "southwest": {
#                         "lat": 35.22742197010728,
#                         "lng": -80.84154842989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png",
#             "id": "51774a813605dd298cba6ffd09c0d4bd782c56ad",
#             "name": "Charlotte Mecklenburg Library - Main Library",
#             "opening_hours": {
#                 "open_now": false,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 1366,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107243913576479081635/photos\">Charlotte Mecklenburg Library - Main Library</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA54Xx686ehYWtAgZYKR3xqcGykjPdUDzDkvtLqXwTtJeSPFtw35_EonIQRTAdO6KXZZxikdNKP-HRFgfzXDTsg5XCYEJl30z8gAr_1ntSLOP_yoI5oOm_wfaJtmH1LK4GEhBndR-H0aPTzYM4wra4NTI2GhRvO3RMCjcd5o3cIGR0ikGAqiO97w",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJH8aoZCOgVogRmUJiaJisjV0",
#             "rating": 4.2,
#             "reference": "CmRbAAAAu71DshsHuGR3Ecb2RqahvkEhk9x5NqAtVGv6y_eCegehqAsm_atl4MEtoSx-WJYLG00ENa0gOWby9VRHGqtedZ_1irpSbsjea60zw_8FvdeI9LuZtTakpbEK2KD8OMJaEhCC9IfOtY5a2h-eQjb5zREjGhQnoFNHrBzLF533lS1e96HQEn6ToQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "library",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "310 N Tryon St, Charlotte"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 35.220619,
#                     "lng": -80.81103
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 35.22179472989273,
#                         "lng": -80.80969742010727
#                     },
#                     "southwest": {
#                         "lat": 35.21909507010729,
#                         "lng": -80.81239707989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png",
#             "id": "8faef7352e6b4aae84479a0bbd18139d9dd44b3e",
#             "name": "Charlotte Mecklenburg Library - Plaza Midwood",
#             "opening_hours": {
#                 "open_now": false,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 993,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105541315007937918025/photos\">Charlotte Mecklenburg Library Plaza Midwood Branch</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA3tz1-GNi4FJTKlKr_U4gOI9xpU2bOLPodBgAAoAe9AHqWPCEkCVZa-6qgvKHgo91Bvf98SIs8AjVjQFfj7x97_mq0jt6Gu7eDEJ1raV0E2XvTaKMg_hs5BR_tikul8XyEhAoAjQo6gqmdELzD0BuxLLtGhT3lgYuXuxbKU2JDKo4uAbjnJVBIw",
#                     "width": 1543
#                 }
#             ],
#             "place_id": "ChIJI8K2vQCgVogRB4YcLnd_h2M",
#             "rating": 4.1,
#             "reference": "CmRbAAAAnDQNevSazvoyAnl4gwtgvbLtT4UN6DBIwlGoLV_sae9uxrMOLMPL8Znj_NYGxWRWqYFPFkZUx16u2zfAfBvPyuss9fIna6ufknOSqxzy5v9jY04HdRXVnpjgN8O3gPd1EhBcNOdNAmu77-jGuiRz5YoFGhTsY0ztc1PxRzrbSxWNkgYY0VEoIg",
#             "scope": "GOOGLE",
#             "types": [
#                 "library",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "1623 Central Ave, Charlotte"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 35.2676379,
#                     "lng": -80.8533522
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 35
272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/library-71.png",
#             "id": "83a6b05dfc55b62cfe80daf329a7ff31271a4416",
#             "name": "Everett Library",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106983853863973595835/photos\">Jason Hazard</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA8vNoYKzZkmreMFzGF_2boLkS9lMKSNZtRzEZCYwcNPYimtR1kWDBnbuJc04AKgdy3dhneoJYQf1vQLHR2YftBSnPxfOqgPEKTLPrg6SwOEQ7zsjvTfihTSlJiPbhrZJ_EhDYZoBtsYp6ltAVGD-8rZrmGhTdb8ouK0vk4UrjFbR_hUBS1rHmgQ",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJoRZUeMefVogRDJ2MYN4lTe4",
#             "rating": 5,
#             "reference": "CmRbAAAA_YzzV-T23QtxTWbQvdV96c9Z044OV0bxgoChZtkRkIhAGj7bEoNo63bc7KVSzSWLI4wYJ7K9xL_byLtoVpYvFAudhB9AJQUtusKycvc4A5IiZcu32t0SVO9gCznokxT-EhBSkN-9sJVttWTBgHQtNWflGhRzKz23iJVk9ZrbzLHwprVs-8Y2eA",
#             "scope": "GOOGLE",
#             "types": [
#                 "library",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "1900 Selwyn Ave, Charlotte"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 35.2266203,
#                     "lng": -80.83765059999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 35.22822957989272,
#                         "lng": -80.83598092010727
#                     },
#                     "southwest": {
#                         "lat": 35.22552992010728,
#                         "lng": -80.83868057989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png",
#             "id": "28486be1eb11a1b32937ebcc3bcf494b184e270f",
#             "name": "ImaginOn: The Joe & Joan Martin Center",
#             "opening_hours": {
#                 "open_now": false,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 1152,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112481514403724504657/photos\">ImaginOn: The Joe &amp; Joan Martin Center</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAEY2XVq4JYXw5IyBHbzPtCALu9dMuW7pWzpRvI_rsKx_1pDDjtBIWTJew_7uh-gGoRj989srcohH0xgQYs8dENciEFza_ooJKrOD_UmSk7vV06GBKO0zS4rEN7m3YC2VrEhBpVAys30XK-NChUhbbliRsGhTJvVEpKsTtgorbPvAEM2b7whcphQ",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJH8aoZCOgVogR-su8pgGKPzo",
#             "rating": 4.8,
#             "reference": "CmRbAAAAxW0_ZDK83El0HGOPPpnFoi-q4KsGrCiM7nUCisaJFVyd93LRY1qqeCa0YF5I5qsL4cxTz5f-rhU1a36YzZ6RN9qGfg17C_VoJVM4UybMakk6D_EtnCnhdkXQ_B8FBYvVEhDwXasW3hfEl9nhu6PAQ777GhQTLGMbO1zVZUpdILUzFcrFWAVtPg",
#             "scope": "GOOGLE",
#             "types": [
#                 "library",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "300 E 7th St, Charlotte"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Print the name and address of the first restaurant that appears
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
# Out:
# Charlotte Mecklenburg Library - Main Library
# 310 N Tryon St, Charlotte

# %%
#Victim API
url2 = "http://clt-charlotte.opendata.arcgis.com/datasets/2564657b1e9a4883ab388badadbeef6d_5.geojson"
response2 = requests.get(url2)
df_victim = pd.DataFrame(response2.json()['features'])
arr2 = []
for b in df_victim["properties"]:
    arr2.append(b)
df_victim = pd.DataFrame(arr2)
df_victim
# Out:
#                 CreationDate      Creator                  EditDate  \
# 0   2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 1   2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 2   2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 3   2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 4   2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 5   2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 6   2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 7   2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 8   2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 9   2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 10  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 11  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 12  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 13  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 14  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 15  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 16  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 17  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 18  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 19  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 20  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 21  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 22  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 23  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 24  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 25  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 26  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 27  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 28  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 29  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# ..                       ...          ...                       ...
# 47  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 48  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 49  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 50  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 51  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 52  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 53  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 54  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 55  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 56  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 57  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 58  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 59  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 60  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 61  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 62  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 63  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 64  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 65  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 66  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 67  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 68  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 69  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 70  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 71  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 72  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 73  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 74  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 75  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 76  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
#
#          Editor  INCIDENT_ID  INDIVIDUAL_AGE INDIVIDUAL_GENDER  \
# 0   CharlotteNC         1649            33.0              Male
# 1   CharlotteNC         1739            25.0              Male
# 2   CharlotteNC         1953            67.0              Male
# 3   CharlotteNC         2421            25.0              Male
# 4   CharlotteNC         1875            19.0              Male
# 5   CharlotteNC         2596            25.0              Male
# 6   CharlotteNC        21268             NaN              Male
# 7   CharlotteNC        22155            28.0              Male
# 8   CharlotteNC        22525             NaN              Male
# 9   CharlotteNC        20897            31.0              Male
# 10  CharlotteNC        22665            27.0              Male
# 11  CharlotteNC         3095            27.0              Male
# 12  CharlotteNC         3750            36.0              Male
# 13  CharlotteNC         3490            33.0              Male
# 14  CharlotteNC         3932            26.0              Male
# 15  CharlotteNC         3908            41.0              Male
# 16  CharlotteNC         4392            42.0              Male
# 17  CharlotteNC         4925            17.0              Male
# 18  CharlotteNC         5822            33.0              Male
# 19  CharlotteNC         5954            16.0              Male
# 20  CharlotteNC         6740            29.0              Male
# 21  CharlotteNC         6788            29.0              Male
# 22  CharlotteNC         6530            52.0              Male
# 23  CharlotteNC         6508            37.0              Male
# 24  CharlotteNC         7699            35.0              Male
# 25  CharlotteNC         7307            36.0              Male
# 26  CharlotteNC         7218            27.0              Male
# 27  CharlotteNC         6867            21.0              Male
# 28  CharlotteNC         9687            17.0              Male
# 29  CharlotteNC        10386            21.0              Male
# ..          ...          ...             ...               ...
# 47  CharlotteNC        15735            25.0              Male
# 48  CharlotteNC        15332            59.0              Male
# 49  CharlotteNC        15735            24.0              Male
# 50  CharlotteNC        15735            27.0              Male
# 51  CharlotteNC        17466            31.0              Male
# 52  CharlotteNC        17590             NaN              Male
# 53  CharlotteNC        17817             NaN              Male
# 54  CharlotteNC        16556            26.0              Male
# 55  CharlotteNC        17939            27.0              Male
# 56  CharlotteNC        18163            20.0            Female
# 57  CharlotteNC        18223            14.0              Male
# 58  CharlotteNC        17016            21.0              Male
# 59  CharlotteNC        17018            21.0              Male
# 60  CharlotteNC        19333            32.0              Male
# 61  CharlotteNC        15821            24.0              Male
# 62  CharlotteNC        19722            33.0              Male
# 63  CharlotteNC        19720            30.0              Male
# 64  CharlotteNC        19693            18.0              Male
# 65  CharlotteNC        20336            25.0              Male
# 66  CharlotteNC        19808             NaN              Male
# 67  CharlotteNC        20421            18.0              Male
# 68  CharlotteNC        20675             NaN              Male
# 69  CharlotteNC        22580            23.0              Male
# 70  CharlotteNC        20244             NaN              Male
# 71  CharlotteNC        20497            40.0              Male
# 72  CharlotteNC        20736            30.0              Male
# 73  CharlotteNC        20904             NaN              Male
# 74  CharlotteNC        21414            25.0              Male
# 75  CharlotteNC        22078             NaN              Male
# 76  CharlotteNC        20825            43.0              Male
#
# 69           Fatal Injury                      Black  35.222887 -80.836920
# 70           Fatal Injury  Asian or Pacific islander  35.245198 -80.935216
# 71       Non-Fatal Injury                      Black  35.156376 -80.756009
# 72       Non-Fatal Injury                      White  35.203083 -80.742284
# 73       Non-Fatal Injury                      Black  35.224407 -80.892911
# 74           Fatal Injury                      White  35.260424 -80.832779
# 75           Fatal Injury                   Hispanic  35.279472 -80.787744
# 76           Fatal Injury                      Black  35.292890 -80.727539
#
#     ObjectID    YR
# 0          1  2005
# 1          2  2005
# 2          3  2005
# 3          4  2005
# 4          5  2005
# 5          6  2005
# 6          7  2017
# 7          8  2017
# 8          9  2017
# 9         10  2016
# 10        11  2018
# 11        12  2006
# 12        13  2006
# 13        14  2006
# 14        15  2006
# 15        16  2006
# 16        17  2006
# 17        18  2007
# 18        19  2007
# 19        20  2007
# 20        21  2008
# 21        22  2008
# 22        23  2008
# 23        24  2008
# 24        25  2008
# 25        26  2008
# 26        27  2008
# 27        28  2008
# 28        29  2010
# 29        30  2010
# ..       ...   ...
# 47        48  2013
# 48        49  2013
# 49        50  2013
# 50        51  2013
# 51        52  2014
# 52        53  2014
# 53        54  2014
# 54        55  2014
# 55        56  2015
# 56        57  2015
# 57        58  2015
# 58        59  2014
# 59        60  2014
# 60        61  2015
# 61        62  2013
# 62        63  2016
# 63        64  2016
# 64        65  2015
# 65        66  2016
# 66        67  2016
# 67        68  2016
# 68        69  2016
# 69        70  2018
# 70        71  2016
# 71        72  2016
# 72        73  2016
# 73        74  2016
# 74        75  2017
# 75        76  2017
# 76        77  2016
#
# [77 rows x 13 columns]

# %%
#Officer Data
url3 = "http://clt-charlotte.opendata.arcgis.com/datasets/635b5f06b7934d11be37a2e391235a1e_6.geojson"
response3 = requests.get(url3)
df3 = pd.DataFrame(response3.json()['features'])
arr3 = []
for b in df3["properties"]:
    arr3.append(b)
df3 = pd.DataFrame(arr3)
#df3

# %%
#http://clt-charlotte.opendata.arcgis.com/datasets/36b534fc414640fa843fc780f6d9aaf5_4.geojson
#Incident Data
url4 = "http://clt-charlotte.opendata.arcgis.com/datasets/36b534fc414640fa843fc780f6d9aaf5_4.geojson"
response4 = requests.get(url4)
df4 = pd.DataFrame(response4.json()['features'])
arr4 = []
for b in df4["properties"]:
    arr4.append(b)
df4 = pd.DataFrame(arr4)
#df4

# %%
df_victim["Latitude"]
# Out:
# 0     35.224496
# 1     35.226991
# 2     35.199025
# 3     35.219339
# 4     35.144363
# 5     35.205423
# 6     35.203018
# 7     35.267345
# 8     35.196748
# 9     35.178978
# 10    35.245948
# 11    35.196759
# 12    35.307636
# 13    35.328493
# 14    35.266889
# 15    35.203154
# 16    35.280184
# 17    35.196550
# 18    35.183119
# 19    35.203381
# 20    35.288883
# 21    35.220053
# 22    35.162905
# 23    35.325941
# 24    35.258041
# 25    35.252694
# 26    35.140304
# 27    35.242488
# 28    35.198285
# 29    35.236462
#         ...
# 47    35.240928
# 48    35.311409
# 49    35.240928
# 50    35.240928
# 51    35.204821
# 52    35.268280
# 53    35.235801
# 54    35.294192
# 55    35.222212
# 56    35.250804
# 57    35.238000
# 58    35.242210
# 59    35.292636
# 60    35.223118
# 61    35.253572
# 62    35.241930
# 63    35.218810
# 64    35.349981
# 65    35.108584
# 66    35.160944
# 67    35.289417
# 68          NaN
# 69    35.222887
# 70    35.245198
# 71    35.156376
# 72    35.203083
# 73    35.224407
# 74    35.260424
# 75    35.279472
# 76    35.292890
# Name: Latitude, Length: 77, dtype: float64

# %%
df_victim["Longitude"]
# Out:
# 0    -80.896504
# 1    -80.729299
# 2    -80.756286
# 3    -80.876367
# 4    -80.861774
# 5    -80.759096
# 6    -80.740502
# 7    -80.848407
# 8    -80.791135
# 9    -80.883495
# 10   -80.910340
# 11   -80.726461
# 12   -80.845673
# 13   -80.783339
# 14   -80.921601
# 15   -80.744067
# 16   -80.816310
# 17   -80.768074
# 18   -80.764790
# 19   -80.755543
# 20   -80.836591
# 21   -80.808023
# 22   -80.876159
# 23   -80.861426
# 24   -80.784238
# 25   -80.849701
# 26   -80.894164
# 27   -80.829595
# 28   -80.726353
# 29   -80.743223
#         ...
# 47   -80.824840
# 48   -80.785750
# 49   -80.824840
# 50   -80.824840
# 51   -80.738578
# 52   -80.853915
# 53   -80.734725
# 54   -80.929070
# 55   -80.843413
# 56   -80.818468
# 57   -80.828523
# 58   -80.858996
# 59   -80.755903
# 60   -80.870996
# 61   -80.647681
# 62   -80.913454
# 63   -80.885417
# 64   -80.852702
# 65   -80.979531
# 66   -80.896387
# 67   -80.758414
# 68          NaN
# 69   -80.836920
# 70   -80.935216
# 71   -80.756009
# 72   -80.742284
# 73   -80.892911
# 74   -80.832779
# 75   -80.787744
# 76   -80.727539
# Name: Longitude, Length: 77, dtype: float64

# %%
#This drops an incident that is missing a latitude or a longitude
df_victim = df_victim.dropna(axis=0, subset=['Latitude', 'Longitude'],how='any')
df_victim=df_victim.reset_index(drop=True)

# %%
df_victim.head()
# Out:
#                CreationDate      Creator                  EditDate  \
# 0  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 1  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 2  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 3  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
# 4  2018-04-02T09:02:13.545Z  CharlotteNC  2018-04-02T09:02:13.545Z
#
#         Editor  INCIDENT_ID  INDIVIDUAL_AGE INDIVIDUAL_GENDER  \
# 0  CharlotteNC         1649            33.0              Male
# 1  CharlotteNC         1739            25.0              Male
# 2  CharlotteNC         1953            67.0              Male
# 3  CharlotteNC         2421            25.0              Male
# 4  CharlotteNC         1875            19.0              Male
#
#   INDIVIDUAL_INJURY_TYPE INDIVIDUAL_RACE   Latitude  Longitude  ObjectID    YR
# 0                   Miss           Black  35.224496 -80.896504         1  2005
# 1       Non-Fatal Injury           White  35.226991 -80.729299         2  2005
# 2           Fatal Injury           White  35.199025 -80.756286         3  2005
# 3                   Miss           Black  35.219339 -80.876367         4  2005
# 4                   Miss           Black  35.144363 -80.861774         5  2005

# %%
df_victim["Latitude"]
# Out:
# 0     35.224496
# 1     35.226991
# 2     35.199025
# 3     35.219339
# 4     35.144363
# 5     35.205423
# 6     35.203018
# 7     35.267345
# 8     35.196748
# 9     35.178978
# 10    35.245948
# 11    35.196759
# 12    35.307636
# 13    35.328493
# 14    35.266889
# 15    35.203154
# 16    35.280184
# 17    35.196550
# 18    35.183119
# 19    35.203381
# 20    35.288883
# 21    35.220053
# 22    35.162905
# 23    35.325941
# 24    35.258041
# 25    35.252694
# 26    35.140304
# 27    35.242488
# 28    35.198285
# 29    35.236462
#         ...
# 46    35.293282
# 47    35.240928
# 48    35.311409
# 49    35.240928
# 50    35.240928
# 51    35.204821
# 52    35.268280
# 53    35.235801
# 54    35.294192
# 55    35.222212
# 56    35.250804
# 57    35.238000
# 58    35.242210
# 59    35.292636
# 60    35.223118
# 61    35.253572
# 62    35.241930
# 63    35.218810
# 64    35.349981
# 65    35.108584
# 66    35.160944
# 67    35.289417
# 68    35.222887
# 69    35.245198
# 70    35.156376
# 71    35.203083
# 72    35.224407
# 73    35.260424
# 74    35.279472
# 75    35.292890
# Name: Latitude, Length: 76, dtype: float64

# %%
#North Carolina has FIPS of 37
#Mecklenburg County is FIPS of 119

# %%
#testing plotly
import plotly.plotly as py
import pandas as pd
import plotly
plotly.tools.set_credentials_file(username='ckarnas', api_key='cAAeEVu4vtfVzgkiW6tN')

#df = pd.read_csv('Public_Art_Charlotte.csv')

#scl = [50,"rgb(150,0,90)"],[60,"rgb(14,154,34)"],[95,"rgb(255, 111, 0)"]

data = [ dict(
    lat = df_victim['Latitude'],
    lon = df_victim['Longitude'],
    #text = df['Globvalue'].astype(str) + ' inches',
    marker = dict(
        color ="rgb(212, 0, 0)", #df['Noon Temp(f)'],
        #colorscale = scl,
        #reversescale = True,
        opacity = 0.7,
        size = 5,
#         colorbar = dict(
#             thickness = 10,
#             titleside = "right",
#             #outlinecolor = "rgba(68, 68, 68, 0)",
#             #ticks = "outside",
#             #ticklen = 3,
#             #showticksuffix = "last",
#             #ticksuffix = " inches",
#             #dtick = 0.1
#         ),
    ),
    type = 'scattergeo'
) ]
# layout = dict(
#     title = 'World Temperature vs Equator location 03-26-2018<br>Source: Open Weather API',
#     geo = dict(
        
#         showframe = False,
#         showcoastlines = False,
#         projection = dict(
#             type = 'Mercator'
#         )
#     )
# )
layout = dict(
    geo = dict(
        lonaxis=dict(range=(-81, -80.6)),
        lataxis=dict(range=(35, 35.4)),
        scope = 'NC',
        showland = True,
        landcolor = "rgb(212, 212, 212)",
        subunitcolor = "rgb(255, 255, 255)",
        countrycolor = "rgb(255, 255, 255)",
        showlakes = True,
        lakecolor = "rgb(255, 255, 255)",
        showsubunits = True,
        showcountries = True,
        resolution = 50,
        
        projection=dict(type="Albers USA"),
#         projection = dict(
#             type = 'conic conformal',
#             rotation = dict(
#                 lon = -100
#             )
#         ),
#         lonaxis = dict(
#             showgrid = True,
#             gridwidth = 1,
#             #range= [ -140.0, -55.0 ],
#             dtick = 5
#         ),
#          lataxis = dict (
#              showgrid = True,
#              gridwidth = 1,
#              #range= [ 20.0, 60.0 ],
#              dtick = 5
#         )
     ),
    title = 'Officer Involved Shootings by CMPD Officers',
)
fig = { 'data':data, 'layout':layout }
py.iplot(fig, filename='CMPD_Shootings')
#This sucks. Not enough details
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ckarnas/4.embed" height="525px" width="100%"></iframe>

# %%
# !pip install mpl_toolkits
# from mpl_toolkits.basemap import Basemap
# import matplotlib.pyplot as plt
# # setup Lambert Conformal basemap.
# # set resolution=None to skip processing of boundary datasets.
# m = Basemap(width=12000000,height=9000000,projection='lcc',
#             resolution=None,lat_1=45.,lat_2=55,lat_0=50,lon_0=-107.)
# m.bluemarble()
# plt.show()
from gmplot import gmplot

# %%
# # Place map
# gmap = gmplot.GoogleMapPlotter(df_victim["Latitude"].head(10).mean(), df_victim["Longitude"].head(10).mean(), 12)

# print(df_victim["Longitude"].head(10).mean())
# arr = []
# for i in range(len(df_victim["Longitude"].head(10))):
#     arr.append((df_victim["Latitude"][i],df_victim["Longitude"][i]))
# print(arr)
# # Polygon
# #golden_gate_park_lats, golden_gate_park_lons = zip(*arr)
# #gmap.plot(golden_gate_park_lats, golden_gate_park_lons, 'cornflowerblue', edge_width=10)

# # Scatter points
# top_attraction_lats, top_attraction_lons = zip(*arr)
# gmap.scatter(top_attraction_lats, top_attraction_lons, 'rgb(200,0,0)', size=120, marker=False)

# # Marker
# hidden_gem_lat, hidden_gem_lon = df_victim["Latitude"].head(10).mean(), df_victim["Longitude"].head(10).mean()
# gmap.marker(hidden_gem_lat, hidden_gem_lon, 'cornflowerblue')

# # Draw
# gmap.draw("my_map.html")
# Out:
# -80.81428645601
# [(35.224496260700001, -80.8965036803), (35.226991161400001, -80.729298943299995), (35.199025124499997, -80.756285778099993), (35.219338700000002, -80.876367382799998), (35.144363259400002, -80.861773972699993), (35.205423107199998, -80.759095584199997), (35.203018235499997, -80.740501783900001), (35.267345300000002, -80.848407398999996), (35.196747899999998, -80.791135198999996), (35.178978144600002, -80.883494836799997)]

# %%
# Place map
gmap = gmplot.GoogleMapPlotter(df_victim["Latitude"].mean(), df_victim["Longitude"].mean(), 11.5)

arr = []
for i in range(len(df_victim["Longitude"])):
    arr.append((df_victim["Latitude"][i],df_victim["Longitude"][i]))
# Polygon
#golden_gate_park_lats, golden_gate_park_lons = zip(*arr)
#gmap.plot(golden_gate_park_lats, golden_gate_park_lons, 'cornflowerblue', edge_width=10)

# Scatter points
top_attraction_lats, top_attraction_lons = zip(*arr)
gmap.scatter(top_attraction_lats, top_attraction_lons, 'rgb(200,0,0)', size=200, marker=False)

# Marker
hidden_gem_lat, hidden_gem_lon = df_victim["Latitude"].head(10).mean(), df_victim["Longitude"].head(10).mean()
gmap.marker(hidden_gem_lat, hidden_gem_lon, 'cornflowerblue')

# Draw
gmap.draw("CMPD_Shootings_Map.html")
